# %% [markdown]
# <a href="https://colab.research.google.com/github/BintangPray/Kelompok-5-P2/blob/main/FINAL_GARCH%20HARGA%20CABAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install arch
# Out:
# Collecting arch
#   Downloading arch-7.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.22.3 in /usr/local/lib/python3.10/dist-packages (from arch) (1.26.4)
# Requirement already satisfied: scipy>=1.8 in /usr/local/lib/python3.10/dist-packages (from arch) (1.13.1)
# Requirement already satisfied: pandas>=1.4 in /usr/local/lib/python3.10/dist-packages (from arch) (2.2.2)
# Requirement already satisfied: statsmodels>=0.12 in /usr/local/lib/python3.10/dist-packages (from arch) (0.14.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.4->arch) (2024.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (0.5.6)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from statsmodels>=0.12->arch) (24.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from patsy>=0.5.6->statsmodels>=0.12->arch) (1.16.0)
# Downloading arch-7.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (985 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 985.1/985.1 kB 10.1 MB/s eta 0:00:00
# Installing collected packages: arch
# Successfully installed arch-7.2.0

# %%
import numpy as np
import pandas as pd
from arch import arch_model
import matplotlib.pyplot as plt

# %% [markdown]
# # Impor Data

# %%
data = pd.read_excel("MPDW.xlsx")
lambda_bc = -0.3535354
data['Boxcox'] = data['Harga']**lambda_bc
data['Diff'] = np.diff(data['Boxcox'], prepend=data['Boxcox'][0])

# %%
data['DiffA'] = data['Diff']*(10**5)
print(data.head())
print(data.shape)
# Out:
#      Tanggal  Harga    Boxcox      Diff      DiffA
# 0 2022-09-01  62070  0.020209  0.000000   0.000000
# 1 2022-09-02  57760  0.020730  0.000521  52.076902
# 2 2022-09-03  59920  0.020463 -0.000267 -26.732745
# 3 2022-09-04  59450  0.020520  0.000057   5.704686
# 4 2022-09-05  61310  0.020297 -0.000222 -22.227596
# (700, 5)

# %%
print(data.tail())
# Out:
#        Tanggal  Harga    Boxcox      Diff      DiffA
# 695 2024-07-27  75460  0.018861  0.000563  56.270016
# 696 2024-07-28  69540  0.019413  0.000553  55.271305
# 697 2024-07-29  79400  0.018524 -0.000889 -88.904388
# 698 2024-07-30  84850  0.018095 -0.000430 -42.970163
# 699 2024-07-31  78630  0.018588  0.000494  49.363180

# %% [markdown]
# # Splitting Data
#
# _Splitting_ data dilakukan dengan membagi data menjadi data latih sebanyak 578 amatan dan data uji sebanyak 122 amatan.

# %%
test_size = 122
train_data = data.iloc[:-test_size]
test_data = data.iloc[-test_size:]

# Menampilkan jumlah data dalam setiap bagian untuk memastikan pemisahan yang benar
print("Jumlah data latih:", len(train_data))
print("Jumlah data uji:", len(test_data))
# Membuat plot data latih dan data uji
plt.figure(figsize=(10, 6))
plt.plot(train_data['Tanggal'], train_data['Harga'], label='Data Latih', color='blue')
plt.plot(test_data['Tanggal'], test_data['Harga'], label='Data Uji', color='red')
plt.ylabel('Harga Cabai Rawit Merah')
plt.legend()
plt.show()
# Out:
# Jumlah data latih: 578
# Jumlah data uji: 122

# %%
print("Jumlah data latih:", len(train_data))
print("Jumlah data uji:", len(test_data))
# Membuat plot data latih dan data uji
plt.figure(figsize=(10, 6))
plt.plot(train_data['Tanggal'], train_data['Boxcox'], label='Data Latih', color='blue')
plt.plot(test_data['Tanggal'], test_data['Boxcox'], label='Data Uji', color='red')
plt.ylabel('Harga Cabai Rawit Merah Transformasi Boxcox')
plt.legend()
plt.show()
# Out:
# Jumlah data latih: 578
# Jumlah data uji: 122

# %%
print("Jumlah data latih:", len(train_data))
print("Jumlah data uji:", len(test_data))
# Membuat plot data latih dan data uji
plt.figure(figsize=(10, 6))
plt.plot(train_data['Tanggal'], train_data['DiffA'], label='Data Latih', color='blue')
plt.plot(test_data['Tanggal'], test_data['DiffA'], label='Data Uji', color='red')
plt.ylabel('Pergerakan Harga Cabai rawit Merah Differencing')
plt.legend()
plt.show()
# Out:
# Jumlah data latih: 578
# Jumlah data uji: 122

# %%
data_diffA = data['DiffA'][1:]
train_data_diffA = data_diffA.iloc[:-test_size]
test_data_diffA = data_diffA.iloc[-test_size:]

print(train_data_diffA.head())
print(train_data_diffA.shape)

print(test_data_diffA.head())
print(test_data_diffA.shape)
# Out:
# 1    52.076902
# 2   -26.732745
# 3     5.704686
# 4   -22.227596
# 5   -29.917305
# Name: DiffA, dtype: float64
# (577,)
# 578   -22.039107
# 579     0.000000
# 580   -19.575676
# 581    -3.241074
# 582   -25.389337
# Name: DiffA, dtype: float64
# (122,)

# %%
import statsmodels.api as sm
import statsmodels.stats.diagnostic as diag

model = sm.tsa.ARIMA(train_data_diffA, order=(1, 0, 0)).fit()
residuals = model.resid
residual_squared = residuals**2

results = []

for lag in range(1, 26):
    lm_stat, lm_pvalue, _, _ = diag.het_arch(residual_squared, nlags=lag)
    results.append({"Lag": lag, "Statistik LM": lm_stat, "p-value": lm_pvalue})

results_df = pd.DataFrame(results)
print(results_df)
# Out:
#     Lag  Statistik LM       p-value
# 0     1     20.128986  7.239121e-06
# 1     2     47.238203  5.525284e-11
# 2     3     51.973264  3.034635e-11
# 3     4     53.443736  6.881175e-11
# 4     5     53.732748  2.378340e-10
# 5     6     53.636878  8.731648e-10
# 6     7     53.640870  2.769681e-09
# 7     8     53.560450  8.399965e-09
# 8     9     53.473630  2.376597e-08
# 9    10     53.399942  6.274910e-08
# 10   11     53.319434  1.570437e-07
# 11   12     53.223181  3.759324e-07
# 12   13     53.134158  8.563688e-07
# 13   14     53.060177  1.858131e-06
# 14   15     52.973612  3.895130e-06
# 15   16     52.903853  7.821275e-06
# 16   17     52.831495  1.519343e-05
# 17   18     52.750796  2.866981e-05
# 18   19     52.671682  5.245661e-05
# 19   20     52.601731  9.298427e-05
# 20   21     52.523301  1.608878e-04
# 21   22     52.440416  2.716854e-04
# 22   23     52.375952  4.450759e-04
# 23   24     52.300308  7.148254e-04
# 24   25     52.214065  1.126169e-03

# %% [markdown]
# # Pemodelan GARCH

# %% [markdown]
# ### Pendugaan Parameter

# %% [markdown]
# GARCH(1,1)

# %%
# Load your time series data (e.g., 'train_data_partial')
# Specify the GARCH(1, 1) model
model_garch11_diffA = arch_model(train_data_diffA, vol='GARCH', mean = 'constant', p=1, q=1)

# Fit the model
result_garch11_diffA = model_garch11_diffA.fit()
# Out:
# Iteration:      1,   Func. Count:      6,   Neg. LLF: 2999.0904037635155
# Iteration:      2,   Func. Count:     12,   Neg. LLF: 2916.558393613606
# Iteration:      3,   Func. Count:     18,   Neg. LLF: 3229.9335541514315
# Iteration:      4,   Func. Count:     25,   Neg. LLF: 2860.3099791859577
# Iteration:      5,   Func. Count:     30,   Neg. LLF: 2860.309959061019
# Iteration:      6,   Func. Count:     35,   Neg. LLF: 2860.309953046737
# Iteration:      7,   Func. Count:     40,   Neg. LLF: 2860.3099181385032
# Iteration:      8,   Func. Count:     45,   Neg. LLF: 2860.3097397239553
# Iteration:      9,   Func. Count:     50,   Neg. LLF: 2860.3088732829597
# Iteration:     10,   Func. Count:     55,   Neg. LLF: 2860.3047160243946
# Iteration:     11,   Func. Count:     60,   Neg. LLF: 2860.289250845336
# Iteration:     12,   Func. Count:     65,   Neg. LLF: 2860.2774843772036
# Iteration:     13,   Func. Count:     70,   Neg. LLF: 2860.2774069019197
# Iteration:     14,   Func. Count:     74,   Neg. LLF: 2860.277406901784
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2860.2774069019197
#             Iterations: 14
#             Function evaluations: 74
#             Gradient evaluations: 14

# %%
# Display model fitting summary
print(result_garch11_diffA.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  DiffA   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2860.28
# Distribution:                  Normal   AIC:                           5728.55
# Method:            Maximum Likelihood   BIC:                           5745.99
#                                         No. Observations:                  577
# Date:                Fri, Nov 15 2024   Df Residuals:                      576
# Time:                        09:05:31   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.4562      1.545      0.943      0.346 [ -1.572,  4.484]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega        674.9823    227.135      2.972  2.961e-03 [2.298e+02,1.120e+03]
# alpha[1]       0.1686  6.008e-02      2.805  5.024e-03   [5.080e-02,  0.286]
# beta[1]        0.3041      0.145      2.104  3.536e-02   [2.084e-02,  0.587]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# GARCH(1,2)

# %%
# Load your time series data (e.g., 'train_data_partial')
# Specify the GARCH(1, 2) model
model_garch12_diffA = arch_model(train_data_diffA, vol='GARCH', mean = 'constant', p=1, q=2)

# Fit the model
result_garch12_diffA = model_garch12_diffA.fit()
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 3976.2186316842653
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 2930.216599099571
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 2891.5003914587255
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 2860.7708352715795
# Iteration:      5,   Func. Count:     35,   Neg. LLF: 2917.120745895464
# Iteration:      6,   Func. Count:     42,   Neg. LLF: 2860.3319020673266
# Iteration:      7,   Func. Count:     48,   Neg. LLF: 2860.3099490450577
# Iteration:      8,   Func. Count:     54,   Neg. LLF: 2860.309902758969
# Iteration:      9,   Func. Count:     60,   Neg. LLF: 2860.309893063918
# Iteration:     10,   Func. Count:     66,   Neg. LLF: 2860.309882194113
# Iteration:     11,   Func. Count:     72,   Neg. LLF: 2860.309837209392
# Iteration:     12,   Func. Count:     78,   Neg. LLF: 2860.3097533138944
# Iteration:     13,   Func. Count:     84,   Neg. LLF: 2860.3094091958615
# Iteration:     14,   Func. Count:     90,   Neg. LLF: 2860.308825940243
# Iteration:     15,   Func. Count:     96,   Neg. LLF: 2860.3066302216994
# Iteration:     16,   Func. Count:    102,   Neg. LLF: 2860.3011327727863
# Iteration:     17,   Func. Count:    108,   Neg. LLF: 2860.2931236159684
# Iteration:     18,   Func. Count:    114,   Neg. LLF: 2860.2828865793545
# Iteration:     19,   Func. Count:    120,   Neg. LLF: 2860.2785808193266
# Iteration:     20,   Func. Count:    126,   Neg. LLF: 2860.277497022801
# Iteration:     21,   Func. Count:    132,   Neg. LLF: 2860.27740891362
# Iteration:     22,   Func. Count:    138,   Neg. LLF: 2860.277406929994
# Iteration:     23,   Func. Count:    143,   Neg. LLF: 2860.277407201062
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2860.277406929994
#             Iterations: 23
#             Function evaluations: 143
#             Gradient evaluations: 23

# %%
# Display model fitting summary
print(result_garch12_diffA.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  DiffA   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2860.28
# Distribution:                  Normal   AIC:                           5730.55
# Method:            Maximum Likelihood   BIC:                           5752.34
#                                         No. Observations:                  577
# Date:                Fri, Nov 15 2024   Df Residuals:                      576
# Time:                        09:05:43   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.4563      1.531      0.951      0.342 [ -1.545,  4.458]
#                                Volatility Model
# =============================================================================
#                  coef    std err          t      P>|t|       95.0% Conf. Int.
# -----------------------------------------------------------------------------
# omega        675.1313    618.503      1.092      0.275 [-5.371e+02,1.887e+03]
# alpha[1]       0.1686  8.113e-02      2.078  3.769e-02    [9.592e-03,  0.328]
# beta[1]        0.3040      0.321      0.946      0.344      [ -0.326,  0.933]
# beta[2]    3.5967e-17      0.796  4.518e-17      1.000      [ -1.560,  1.560]
# =============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# GARCH(2,1)

# %%
# Load your time series data (e.g., 'train_data_partial')
# Specify the GARCH(2, 1) model
model_garch21_diffA = arch_model(train_data_diffA, vol='GARCH', mean = 'constant', p=2, q=1)

# Fit the model
result_garch21_diffA = model_garch21_diffA.fit()
# Out:
# Iteration:      1,   Func. Count:      7,   Neg. LLF: 2929.498349048577
# Iteration:      2,   Func. Count:     15,   Neg. LLF: 2910.0785070504635
# Iteration:      3,   Func. Count:     22,   Neg. LLF: 2936.0721985967034
# Iteration:      4,   Func. Count:     29,   Neg. LLF: 2860.6873400770983
# Iteration:      5,   Func. Count:     36,   Neg. LLF: 2888.158341683441
# Iteration:      6,   Func. Count:     44,   Neg. LLF: 2859.758016004389
# Iteration:      7,   Func. Count:     51,   Neg. LLF: 2859.6698270557526
# Iteration:      8,   Func. Count:     57,   Neg. LLF: 2859.6697771248932
# Iteration:      9,   Func. Count:     63,   Neg. LLF: 2859.669711041269
# Iteration:     10,   Func. Count:     69,   Neg. LLF: 2859.6692754984037
# Iteration:     11,   Func. Count:     75,   Neg. LLF: 2859.6677301188884
# Iteration:     12,   Func. Count:     81,   Neg. LLF: 2859.664846499598
# Iteration:     13,   Func. Count:     87,   Neg. LLF: 2859.655827233176
# Iteration:     14,   Func. Count:     93,   Neg. LLF: 2859.6351857561876
# Iteration:     15,   Func. Count:     99,   Neg. LLF: 2859.5767222596915
# Iteration:     16,   Func. Count:    105,   Neg. LLF: 2859.447827467717
# Iteration:     17,   Func. Count:    111,   Neg. LLF: 2859.1477709850733
# Iteration:     18,   Func. Count:    117,   Neg. LLF: 2858.6649724025087
# Iteration:     19,   Func. Count:    123,   Neg. LLF: 2858.590171140658
# Iteration:     20,   Func. Count:    129,   Neg. LLF: 2858.4636753679915
# Iteration:     21,   Func. Count:    135,   Neg. LLF: 2858.462469923964
# Iteration:     22,   Func. Count:    141,   Neg. LLF: 2858.462376611568
# Iteration:     23,   Func. Count:    147,   Neg. LLF: 2858.462375248696
# Iteration:     24,   Func. Count:    153,   Neg. LLF: 2858.488594910028
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2858.462375150806
#             Iterations: 24
#             Function evaluations: 157
#             Gradient evaluations: 24

# %%
# Display model fitting summary
print(result_garch21_diffA.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  DiffA   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2858.46
# Distribution:                  Normal   AIC:                           5726.92
# Method:            Maximum Likelihood   BIC:                           5748.71
#                                         No. Observations:                  577
# Date:                Fri, Nov 15 2024   Df Residuals:                      576
# Time:                        09:05:51   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.5622      1.535      1.018      0.309 [ -1.446,  4.570]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega        982.1873    365.364      2.688  7.183e-03 [2.661e+02,1.698e+03]
# alpha[1]       0.1493  5.924e-02      2.520  1.172e-02   [3.320e-02,  0.265]
# alpha[2]       0.0752  5.664e-02      1.327      0.185  [-3.586e-02,  0.186]
# beta[1]        0.0000      0.295      0.000      1.000     [ -0.579,  0.579]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# GARCH(2,2)

# %%
# Load your time series data (e.g., 'train_data_partial')
# Specify the GARCH(2, 2) model
model_garch22_diffA = arch_model(train_data_diffA, vol='GARCH', mean = 'constant', p=2, q=2)

# Fit the model
result_garch22_diffA = model_garch22_diffA.fit()
# Out:
# Iteration:      1,   Func. Count:      8,   Neg. LLF: 2929.488925900695
# Iteration:      2,   Func. Count:     17,   Neg. LLF: 2910.118212634776
# Iteration:      3,   Func. Count:     25,   Neg. LLF: 2931.4796682389674
# Iteration:      4,   Func. Count:     33,   Neg. LLF: 2860.6719873584575
# Iteration:      5,   Func. Count:     40,   Neg. LLF: 2881.693838854041
# Iteration:      6,   Func. Count:     48,   Neg. LLF: 2861.7091437618674
# Iteration:      7,   Func. Count:     56,   Neg. LLF: 2859.6730298339767
# Iteration:      8,   Func. Count:     63,   Neg. LLF: 2859.6700422318977
# Iteration:      9,   Func. Count:     70,   Neg. LLF: 2859.6697392066453
# Iteration:     10,   Func. Count:     77,   Neg. LLF: 2859.669683443154
# Iteration:     11,   Func. Count:     84,   Neg. LLF: 2859.6696138522148
# Iteration:     12,   Func. Count:     91,   Neg. LLF: 2859.6692431896395
# Iteration:     13,   Func. Count:     98,   Neg. LLF: 2859.6684370947023
# Iteration:     14,   Func. Count:    105,   Neg. LLF: 2859.6660611500083
# Iteration:     15,   Func. Count:    112,   Neg. LLF: 2859.660119047102
# Iteration:     16,   Func. Count:    119,   Neg. LLF: 2859.6453189535587
# Iteration:     17,   Func. Count:    126,   Neg. LLF: 2859.6067459083743
# Iteration:     18,   Func. Count:    133,   Neg. LLF: 2859.519673120496
# Iteration:     19,   Func. Count:    140,   Neg. LLF: 2859.3198143577597
# Iteration:     20,   Func. Count:    147,   Neg. LLF: 2858.7782221226093
# Iteration:     21,   Func. Count:    154,   Neg. LLF: 2858.6654192518863
# Iteration:     22,   Func. Count:    161,   Neg. LLF: 2858.4775258579516
# Iteration:     23,   Func. Count:    168,   Neg. LLF: 2858.464616850658
# Iteration:     24,   Func. Count:    175,   Neg. LLF: 2858.4624673848525
# Iteration:     25,   Func. Count:    182,   Neg. LLF: 2858.4623802755423
# Iteration:     26,   Func. Count:    189,   Neg. LLF: 2858.4623790088967
# Iteration:     27,   Func. Count:    196,   Neg. LLF: 2858.462447161499
# Optimization terminated successfully    (Exit mode 0)
#             Current function value: 2858.4623783442707
#             Iterations: 27
#             Function evaluations: 197
#             Gradient evaluations: 27

# %%
# Display model fitting summary
print(result_garch22_diffA.summary())
# Out:
#                      Constant Mean - GARCH Model Results
# ==============================================================================
# Dep. Variable:                  DiffA   R-squared:                       0.000
# Mean Model:             Constant Mean   Adj. R-squared:                  0.000
# Vol Model:                      GARCH   Log-Likelihood:               -2858.46
# Distribution:                  Normal   AIC:                           5728.92
# Method:            Maximum Likelihood   BIC:                           5755.07
#                                         No. Observations:                  577
# Date:                Fri, Nov 15 2024   Df Residuals:                      576
# Time:                        09:05:59   Df Model:                            1
#                                Mean Model
# ========================================================================
#                  coef    std err          t      P>|t|  95.0% Conf. Int.
# ------------------------------------------------------------------------
# mu             1.5627      1.542      1.013      0.311 [ -1.460,  4.585]
#                               Volatility Model
# ============================================================================
#                  coef    std err          t      P>|t|      95.0% Conf. Int.
# ----------------------------------------------------------------------------
# omega        982.4203    360.244      2.727  6.389e-03 [2.764e+02,1.688e+03]
# alpha[1]       0.1493  5.720e-02      2.611  9.038e-03   [3.722e-02,  0.261]
# alpha[2]       0.0752  4.816e-02      1.561      0.119  [-1.923e-02,  0.170]
# beta[1]        0.0000      0.326      0.000      1.000     [ -0.638,  0.638]
# beta[2]    2.3589e-12      0.105  2.250e-11      1.000     [ -0.206,  0.206]
# ============================================================================
#
# Covariance estimator: robust

# %% [markdown]
# Model GARCH(1,1) dipilih sebagai model tentatif terbaik karena memiliki seluruh parameter signifikan

# %%
fig = result_garch11_diffA.plot()

# %%
garch_stresidual = result_garch11_diffA.resid / result_garch11_diffA.conditional_volatility
plt.plot(garch_stresidual)

# %% [markdown]
# ### Diagnostik Sisaan: Uji Kebebasan Sisaan (Ljung-Box)
#
# $H_0$: Sisaan saling bebas
#
# $H_1$: Sisaan tidak saling bebas

# %%
import statsmodels.api as sm
result_df = sm.stats.acorr_ljungbox(abs(garch_stresidual), lags=[10], return_df=True)
print(result_df)
# Out:
#      lb_stat  lb_pvalue
# 10  4.462929   0.924057

# %% [markdown]
# ### Diagnostik Sisaan: Uji Normalitas Sisaan (Kolmogorov-Smirnov)
#
# $H_0$: Sisaan menyebar normal
#
# $H_1$: Sisaan tidak menyebar normal

# %%
from scipy import stats
result_norm = stats.kstest(garch_stresidual, 'norm')
print(result_norm.pvalue)
# Out:
# 2.6984149222930573e-05

# %% [markdown]
# ### Diagnostik Sisaan: Uji Nilai Harapan Sisaan (t-test)
#
# $H_0$: Nilai harapan sisaan nol
#
# $H_1$: Nilai harapan sisaan tidak nol

# %%
result_harapan = stats.ttest_1samp(garch_stresidual, 0)
print(result_harapan.pvalue)
# Out:
# 0.8324486435310421

# %% [markdown]
# ### Diagnostik Sisaan: Ragam Sisaan Homogen (Arch-LM)
#
# $H_0$: Ragam sisaan homogen
#
# $H_1$: Ragam sisaan tidak homogen / Ada heteroskedastisitas

# %%
from statsmodels.stats.diagnostic import het_arch
arch_lm_test = het_arch(garch_stresidual)
print(f"LM Statistic: {arch_lm_test[0]:.4f}")
print(f"p-value: {arch_lm_test[1]:.4f}")
# Out:
# LM Statistic: 4.2105
# p-value: 0.9374

# %%
from google.colab import files

garch_stresidual.to_excel("garch_stresidual_akhir.xlsx", index=False)
files.download("garch_stresidual_akhir.xlsx")

# %%
result_garch11_diffA.resid.to_excel("garch_stresidual_nonnormal_akhir.xlsx", index=False)
files.download("garch_stresidual_nonnormal_akhir.xlsx")

# %% [markdown]
# # Prediksi
#
# Pendugaan nilai amatan menggunakan model GARCH(1,1) dilakukan pada data latih dan uji untuk menghitung nilai keakuratan model.

# %%
np.random.seed(42)
epsilon_train = np.random.normal(0, 1, 577)

# %% [markdown]
# ### Prediksi pada Data Latih

# %%
predicted_train = result_garch11_diffA.conditional_volatility * epsilon_train + 1.4562
predicted_train
# Out:
# 1      16.692131
# 2      -3.704261
# 3      24.195049
# 4      50.875114
# 5      -6.273391
#          ...
# 573    13.497949
# 574    -6.303338
# 575    28.609609
# 576   -73.403789
# 577     9.570626
# Name: cond_vol, Length: 577, dtype: float64

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(train_data['DiffA'])
preds, = plt.plot(result_garch11_diffA.conditional_volatility)
plt.title('Volatility Prediction in Train Data', fontsize=20)
plt.legend(['Actual Returns', 'Predicted Volatility'], fontsize=10)

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(train_data['DiffA'])
preds, = plt.plot(predicted_train)
plt.title('Return Prediction in Train Data', fontsize=20)
plt.legend(['Actual Returns', 'Predicted Returns'], fontsize=10)

# %%
from google.colab import files

predicted_train.to_excel("predicted_train_akhir.xlsx", index=False)
files.download("predicted_train_akhir.xlsx")

# %% [markdown]
# ### Prediksi pada Data Uji

# %%
condvar_test = []

for i in range(test_size):
    train = data_diffA[:-(test_size-i)]
    model = arch_model(train, p=1, q=1)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    condvar_test.append(np.sqrt(pred.variance.values[-1,:][0]))

# %%
condvar_test
# Out:
# [32.72916591281901,
#  33.05657353097537,
#  31.70508044406144,
#  32.428596169132945,
#  31.523934882458157,
#  33.05498781540611,
#  32.038042904351954,
#  43.158630844016706,
#  35.21948699842364,
#  40.096328190393386,
#  34.85907315005445,
#  33.118949911570596,
#  32.60855717083582,
#  31.73348695758781,
#  32.12747058940726,
#  40.68126010368565,
#  35.533294851221086,
#  32.59542523522714,
#  35.40876385370566,
#  36.555879829076304,
#  32.92359709053812,
#  31.83077328338614,
#  38.40055544135296,
#  34.82784200147726,
#  32.35664267444192,
#  33.316932452472365,
#  35.03788339070688,
#  36.35968799870112,
#  33.183261016141195,
#  32.107609684469615,
#  31.967342547752985,
#  31.379055856084847,
#  32.07820692186642,
#  35.5136465071074,
#  40.62087383358247,
#  38.6263041623697,
#  33.86259731123132,
#  33.34102161590827,
#  33.53445454553477,
#  34.573785604982916,
#  32.191070935714734,
#  42.9901840519187,
#  38.50513789077743,
#  34.44070568201053,
#  32.66798056440426,
#  31.605518472724654,
#  33.18042974149507,
#  32.6671124956427,
#  34.05721359049265,
#  35.573922705464135,
#  33.02843574330241,
#  33.50783589816365,
#  32.51912779207119,
#  32.58606696738077,
#  35.04631349492512,
#  32.45111832221589,
#  34.510254542624075,
#  32.75648138542254,
#  35.29515701443,
#  32.39732100570749,
#  31.900863021795423,
#  31.642808345093513,
#  42.760036628592495,
#  43.18724613056286,
#  35.21238425488557,
#  32.379781842433886,
#  40.9779312301403,
#  37.50128678976327,
#  33.26734227733871,
#  31.834836267581032,
#  32.60474175811397,
#  33.852683547418756,
#  51.50981995146533,
#  38.52172886863786,
#  36.46666332229388,
#  37.42117694660615,
#  33.64424439702303,
#  38.51120204079449,
#  79.47029758648478,
#  55.295489619912125,
#  57.34200365846471,
#  40.48186446732568,
#  38.28202783759131,
#  40.22589828748904,
#  37.68610131389504,
#  52.61713445072862,
#  39.33886840833051,
#  38.4737057207639,
#  37.56602946453485,
#  33.63527523865899,
#  34.57135247004536,
#  35.23614573565825,
#  43.471983833932676,
#  36.25730578843853,
#  33.570750115518635,
#  36.16521500457368,
#  34.310262731061336,
#  32.45164452889659,
#  32.10337398616918,
#  33.61042459753147,
#  32.74061888341907,
#  33.62198782988603,
#  32.892084697208766,
#  32.63093212962014,
#  32.02697371814079,
#  34.326993915748474,
#  33.605145227490105,
#  64.9607780758443,
#  44.71983938044866,
#  43.65694028534184,
#  50.32121199639847,
#  39.5658012257613,
#  44.68814165164843,
#  38.18847143416143,
#  35.81541590885946,
#  57.725895016612256,
#  44.206350280482,
#  46.83172355943687,
#  44.33088655670988,
#  43.24491280212928,
#  52.71413471780497,
#  44.32206623567769]

# %%
condvar_test = pd.Series(condvar_test, index=data_diffA.index[-122:])
print(condvar_test)
# Out:
# 578    32.729166
# 579    33.056574
# 580    31.705080
# 581    32.428596
# 582    31.523935
#          ...
# 695    46.831724
# 696    44.330887
# 697    43.244913
# 698    52.714135
# 699    44.322066
# Length: 122, dtype: float64

# %%
np.random.seed(42)
epsilon_test = np.random.normal(0, 1, 122)

# %%
predicted_test = condvar_test * epsilon_test + 1.4562
predicted_test
# Out:
# 578    17.713240
# 579    -3.114344
# 580    21.991217
# 581    50.845920
# 582    -5.925236
#          ...
# 695   -53.275007
# 696    52.118549
# 697    33.973478
# 698    43.154765
# 699   -38.849731
# Length: 122, dtype: float64

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(test_data['DiffA'])
preds, = plt.plot(condvar_test)
plt.title('Volatility Prediction in Train Data', fontsize=20)
plt.legend(['Actual Returns', 'Predicted Volatility'], fontsize=10)

# %%
plt.figure(figsize=(10,4))
true, = plt.plot(data_diffA[-122:])
preds, = plt.plot(predicted_test)
plt.title('Return Prediction in Test Data', fontsize=20)
plt.legend(['Actual Returns', 'Predicted Returns'], fontsize=10)

# %%
from google.colab import files

predicted_test.to_excel("predicted_test_akhir.xlsx", index=False)
files.download("predicted_test_akhir.xlsx")

# %% [markdown]
# # Transformasi Balik

# %%
pt_1 = data['Harga'][577]
hasil_prediksi_test_balik = np.r_[pt_1, predicted_test].cumsum()

pt = data['Harga'][0]
hasil_prediksi_train_balik = np.r_[pt, predicted_train].cumsum()

pt = 0
residual_nonnormal_train_balik = np.r_[pt, result_garch11_diffA.resid].cumsum()

pt = 0
residual_train_balik = np.r_[pt, garch_stresidual].cumsum()

# %%
A_prediksi_test = pd.DataFrame(hasil_prediksi_test_balik, columns=['Prediksi_Uji'])
A_prediksi_train = pd.DataFrame(hasil_prediksi_train_balik, columns=['Prediksi_Train'])
A_residual_nonnormal_train = pd.DataFrame(residual_nonnormal_train_balik, columns=['Residual_non'])
A_residual_train_balik = pd.DataFrame(residual_train_balik, columns=['Residual'])

A_prediksi_test.to_excel("A_prediksi_test_akhir.xlsx", index=False)
files.download("A_prediksi_test_akhir.xlsx")

A_prediksi_train.to_excel("A_prediksi_train_akhir.xlsx", index=False)
files.download("A_prediksi_train_akhir.xlsx")

A_residual_nonnormal_train.to_excel("A_residual_nonnormal_train_akhir.xlsx", index=False)
files.download("A_residual_nonnormal_train_akhir.xlsx")

A_residual_train_balik.to_excel("A_residual_train_balik_akhir.xlsx", index=False)
files.download("A_residual_train_balik_akhir.xlsx")

# %%
print(hasil_prediksi_test_balik)
# Out:
# [52080.         52097.71323993 52094.59889589 52116.59011309
#  52167.43603326 52161.51079752 52155.22760326 52207.2786912
#  52241.85632337 52226.77787634 52249.98874191 52235.29063066
#  52221.32235028 52230.66859084 52171.40973715 52117.44869022
#  52096.03032499 52061.49729816 52073.19652359 52042.50071353
#  51992.32890914 52042.03953868 52036.30910445 52040.35842502
#  51992.1937203  51976.035523   51981.18732343 51942.31514468
#  51957.43160741 51938.95665698 51931.04726792 51913.26850653
#  51972.84744715 51973.87068038 51937.76370834 51972.63240144
#  51926.93192328 51935.46078709 51871.57958313 51828.49578844
#  51836.75822661 51861.98645667 51870.80981062 51867.81295756
#  51858.8989338  51812.05480615 51790.75995673 51776.93196435
#  51812.92129503 51826.08017652 51764.8181223  51776.97830886
#  51765.531235   51744.97452197 51766.36284648 51803.95177896
#  51835.62906029 51808.12364995 51799.45114052 51812.59933534
#  51845.66058398 51831.83071226 51827.41214084 51781.56141683
#  51731.35674693 51761.42391841 51806.79487466 51805.30024885
#  51844.39022385 51857.87709328 51838.79601152 51852.03542191
#  51905.55828708 51905.16909425 51966.89807294 51872.82091024
#  51905.03366929 51909.41850212 51899.35956964 51908.10802586
#  51799.66062957 51788.52040337 51804.43318609 51862.46616706
#  51843.07448197 51814.06171014 51789.11689232 51826.58397576
#  51840.68844921 51822.24366179 51840.96375317 51845.77605535
#  51881.3635714  51852.30013065 51841.87618401 51830.16901918
#  51778.69688642 51790.31305093 51800.24092382 51801.86128303
#  51795.43290987 51750.54899583 51737.86226391 51728.045869
#  51703.32301388 51699.61372063 51714.93977194 51779.78152307
#  51792.57843363 51805.55224573 51803.75836484 51708.65967174
#  51709.06682901 51713.21460517 51808.73825621 51803.30496826
#  51822.16825848 51822.08997783 51768.81497104 51820.93351959
#  51854.90699802 51898.06176264 51859.21203164]

# %%
plt.plot(train_data['Harga'], label='Data Asli (Train)')
plt.plot(range(578, 578 + len(hasil_prediksi_test_balik)), hasil_prediksi_test_balik, label='Hasil Prediksi')
plt.legend()
plt.show()

# %%
def calculate_mape(actual, predicted):
    return np.mean(np.abs((actual - predicted) / actual)) * 100

# Hitung MAPE
mape_value = calculate_mape(test_data['Harga'], hasil_prediksi_test_balik[-1])
print(f'MAPE: {mape_value:.2f}%')
# Out:
# MAPE: 15.14%

# %% [markdown]
# # Prediksi Keseluruhan Data

# %%
condvar_test = []

for i in range(700):
    full = data_diffA
    model = arch_model(full, p=1, q=1)
    model_fit = model.fit(disp='off')
    pred = model_fit.forecast(horizon=1)
    condvar_test.append(np.sqrt(pred.variance.values[-1,:][0]))

#        62470.07121719, 62520.74100271, 62532.91920499, 62548.60292057,
#        62532.70147914, 62513.60859606, 62496.8355904 , 62514.91510127,
#        62498.62984383, 62512.29796262, 62601.21732722, 62639.38514619,
#        62627.10180736, 62679.1805045 , 62663.43927278, 62579.00323365,
#        62537.97587144, 62460.59169428, 62447.23413795, 62449.4665397 ,
#        62521.57247284, 62536.80630207, 62529.02899612, 62565.43865519,
#        62473.71146064, 62485.09711373, 62519.03971798, 62458.18417932,
#        62507.84135727, 62523.56273777, 62507.51754952, 62535.64093811,
#        62632.7904535 , 62641.91100354, 62653.82790974, 62635.92536323,
#        62601.56675675, 62638.01561852, 62603.39406399, 62607.86626436,
#        62589.19265044, 62610.83439309, 62626.35204265, 62671.53306292,
#        62651.49575272, 62641.578672  , 62601.78704554, 62584.51949129,
#        62601.87618393, 62635.23399061, 62597.82757786, 62635.93139107,
#        62694.51794259, 62713.39743983, 62793.94703768, 62762.79360771,
#        62711.79659517, 62638.29257447, 62702.79624461, 62731.82923418,
#        62730.94294148, 62744.19779843, 62698.22275822, 62802.74975212,
#        62809.65169229, 62815.71809333, 62847.76011836, 62869.48738583,
#        62880.37868158, 62848.52208848, 62869.84727694, 62950.61722609,
#        63008.77317055, 63077.37068815, 63057.28283705, 63017.03433628,
#        63013.18952546, 63016.99412832, 63064.56260357, 62994.69363468,
#        63060.60934122, 63055.40664871, 63038.87289259, 62997.67619797,
#        62929.39213307, 62965.539032  , 62970.08505515, 62917.17871343,
#        62864.05669033, 62851.36198876, 62923.1554    , 62913.67169813,
#        62851.78127148, 62842.88117497, 62832.84404487, 62720.64593746,
#        62719.81400071, 62711.53797701, 62742.33425047, 62821.71060516,
#        62870.64339024, 62860.76787262, 62815.59199185, 62925.4967345 ,
#        62929.44856409, 62931.49178321, 62931.93128491, 62941.73532791,
#        62937.10777846, 62914.38826524, 62892.79830778, 62892.87419384,
#        62871.42896187, 62842.84385704, 62848.78532299, 62839.49607355,
#        62904.33472306, 62794.07167883, 62841.52701476, 62895.49671209,
#        62809.57447834, 62796.58886958, 62782.39151792, 62724.53125861,
#        62693.20809907, 62647.86154269, 62723.16329499, 62764.05158606,
#        62819.09465595, 62850.96412483, 62804.83894153, 62784.190398  ,
#        62806.27020373, 62756.22253721, 62787.72647502, 62779.05469402,
#        62764.71490222, 62796.13293358, 62816.31162572, 62802.55570708,
#        62852.86929091, 62808.76647415, 62836.17991451, 62862.63105186,
#        62851.04210358, 62866.24245662, 62814.9732492 , 62855.37051896,
#        62849.03442843])

# %%
A_hasil_prediksi_penuh_balik = pd.DataFrame(hasil_prediksi_penuh_balik, columns=['Residual'])

A_hasil_prediksi_penuh_balik.to_excel("A_prediksi_seluruh_akhir.xlsx", index=False)
files.download("A_prediksi_seluruh_akhir.xlsx")

# %% [markdown]
# # Peramalan
#
# Peramalan (_forecasting_) terhadap data dilakukan hingga 31 periode ke depan.

# %%
from datetime import datetime, timedelta

data_diffA.index = pd.to_datetime(data_diffA.index)

pred = result_garch11_diffA.forecast(horizon=31)
future_dates = [data_diffA.index[-1] + timedelta(days=i) for i in range(1,32)]
condvar_forecast = pd.Series(np.sqrt(pred.variance.values[-1,:]), index=future_dates)

# %%
plt.figure(figsize=(10,4))
plt.plot(condvar_forecast)
plt.title('Volatility Prediction - Next 1 Month', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Volatility Prediction - Next 1 Month')

# %%
np.random.seed(42)
epsilon_forecast = np.random.normal(0, 1, 31)

# %%
predicted_forecast = condvar_forecast * epsilon_forecast + 1.4562
predicted_forecast
# Out:
# 1970-01-02 00:00:00.000000699    17.713240
# 1970-01-03 00:00:00.000000699    -3.295950
# 1970-01-04 00:00:00.000000699    24.202341
# 1970-01-05 00:00:00.000000699    55.474154
# 1970-01-06 00:00:00.000000699    -6.886909
# 1970-01-07 00:00:00.000000699    -6.904360
# 1970-01-08 00:00:00.000000699    57.904126
# 1970-01-09 00:00:00.000000699    28.900828
# 1970-01-10 00:00:00.000000699   -15.336723
# 1970-01-11 00:00:00.000000699    20.865450
# 1970-01-12 00:00:00.000000699   -15.122694
# 1970-01-13 00:00:00.000000699   -15.205808
# 1970-01-14 00:00:00.000000699    10.112771
# 1970-01-15 00:00:00.000000699   -66.994701
# 1970-01-16 00:00:00.000000699   -60.255867
# 1970-01-17 00:00:00.000000699   -18.660681
# 1970-01-18 00:00:00.000000699   -34.779736
# 1970-01-19 00:00:00.000000699    12.698992
# 1970-01-20 00:00:00.000000699   -31.030080
# 1970-01-21 00:00:00.000000699   -49.071641
# 1970-01-22 00:00:00.000000699    53.892563
# 1970-01-23 00:00:00.000000699    -6.621375
# 1970-01-24 00:00:00.000000699     3.872150
# 1970-01-25 00:00:00.000000699   -49.516868
# 1970-01-26 00:00:00.000000699   -18.020124
# 1970-01-27 00:00:00.000000699     5.424666
# 1970-01-28 00:00:00.000000699   -39.722778
# 1970-01-29 00:00:00.000000699    14.897509
# 1970-01-30 00:00:00.000000699   -20.032788
# 1970-01-31 00:00:00.000000699    -8.979697
# 1970-02-01 00:00:00.000000699   -20.070995
# dtype: float64

# %%
plt.figure(figsize=(10,4))
plt.plot(predicted_forecast)
plt.title('Return Forecast - Next 1 Month', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Return Forecast - Next 1 Month')

# %%
pt_1 = data['Harga'][699]
hasil_forecast_balik = np.r_[pt_1, predicted_forecast].cumsum()
A_hasil_forecast_balik = pd.DataFrame(hasil_forecast_balik, columns=['Forecast'])
hasil_forecast_balik
# Out:
# array([78630.        , 78647.71323993, 78644.41729036, 78668.6196317 ,
#        78724.09378614, 78717.20687717, 78710.30251687, 78768.20664272,
#        78797.10747035, 78781.77074691, 78802.63619719, 78787.51350294,
#        78772.30769521, 78782.42046659, 78715.4257652 , 78655.16989805,
#        78636.50921679, 78601.72948085, 78614.42847249, 78583.39839268,
#        78534.32675187, 78588.21931503, 78581.59793976, 78585.47008935,
#        78535.95322092, 78517.93309648, 78523.3577625 , 78483.63498429,
#        78498.53249345, 78478.49970513, 78469.520008  , 78449.44901274])

# %%
A_hasil_forecast_balik.to_excel("A_forecast_Garch_akhir.xlsx", index=False)
files.download("A_forecast_Garch_akhir.xlsx")
